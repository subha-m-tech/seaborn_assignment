# %%
import pandas as pd

# %%
dataset = pd.read_csv("preprocessed_placement.csv")

# %%
dataset
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p         salary gender    ssc_b  \
# 0    67.00  91.00     58.00     55.0  58.80  270000.000000      M   Others
# 1    79.33  78.33     77.48     86.5  66.28  200000.000000      M  Central
# 2    65.00  68.00     64.00     75.0  57.80  250000.000000      M  Central
# 3    56.00  52.00     52.00     66.0  59.43  288655.405405      M  Central
# 4    85.80  73.60     73.30     96.8  55.50  425000.000000      M  Central
# ..     ...    ...       ...      ...    ...            ...    ...      ...
# 210  80.60  82.00     77.60     91.0  74.49  400000.000000      M   Others
# 211  58.00  60.00     72.00     74.0  53.62  275000.000000      M   Others
# 212  67.00  67.00     73.00     59.0  69.72  295000.000000      M   Others
# 213  74.00  66.00     58.00     70.0  60.23  204000.000000      F   Others
# 214  62.00  58.00     53.00     89.0  60.22  288655.405405      M  Central
#
#        hsc_b     hsc_s   degree_t workex specialisation      status
# ...

# %%
dataset.shape # it returns  tuple (rows, columns)
# Out:
# (215, 14)

# %%
dataset.shape[0] #rows
# Out:
# 215

# %%
dataset.shape[1] # columns
# Out:
# 14

# %% [markdown]
# # Univariate Analysis

# %%
import seaborn as sns

# %%
sns.distplot(dataset['ssc_p'], hist=True, kde=True, kde_kws= {'color': 'blue'}, color='green') 
# hist shows the details of repetition or frequency
# Out:
# /var/folders/52/3smrrwzs1674_yymbpt0326h0000gn/T/ipykernel_3244/614921524.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['ssc_p'], hist=True, kde=True, kde_kws= {'color': 'blue'}, color='green')
# <Axes: xlabel='ssc_p', ylabel='Density'>

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Bivariate Analysis

# %%
sns.jointplot(x='ssc_p', y= 'salary', data=dataset) # use join plot if you want to see histrogram and scatter plot
plt.show()

# %%
# Use join plot if you want to see histrogram and scatter plot. if you want hexagon kind of scatter plots use hex in kind
sns.jointplot(x='ssc_p', y= 'salary', data=dataset, kind='hex')
plt.show()

# %%
# use join plot if you want to see histrogram and scatter plot. if you want kernel density 
# estimation kind of scatter plots use kde in kind
sns.jointplot(x='ssc_p', y= 'salary', data=dataset, kind='kde') 
plt.show()

# %%
#hue is for differentiation, diag_kind -  diagnoal, palette - color combination husl
sns.pairplot(dataset, hue='gender', diag_kind='hist', kind= 'scatter',palette= 'husl')
plt.show()

# %% [markdown]
# # Categorical with numerical plots

# %%
# if you want to calculate how much 10th marks students got in each 10th board
# in this case use stripplot
sns.stripplot(x='ssc_b', y= 'ssc_p', data=dataset)
plt.show()

# %%
#Jitter in a strip plot is like adding a little randomness to each data point's position along the x-axis, 
#preventing them from overlapping too much and helping to see the distribution clearly
sns.stripplot(x='ssc_b', y= 'ssc_p', data=dataset, jitter=True)
plt.show()

# %%
# A swarm plot is a type of scatter plot that is used for representing categorical values. 
# It is very similar to the strip plot, but it avoids the overlapping of points. We can use the seaborn.swarmplot() to create such graphs.
# It is not advisable to use this type of graph when the sample size is large
sns.swarmplot(x='ssc_b', y= 'ssc_p', data=dataset)
plt.show()

# %% [markdown]
# # Distribution Observation

# %%
# if you want to check density of particular categorical column with numerical variable then use violinplot
sns.violinplot(x='gender', y= 'ssc_p', data=dataset)
plt.show()

# %%
sns.violinplot(x='specialisation', y= 'salary', data=dataset, hue= 'gender')
plt.show()

# %%
sns.boxplot(x= 'ssc_b', y='ssc_p', data=dataset, hue='gender')
plt.show()

# %%
sns.barplot(x= 'ssc_b', y='ssc_p', data=dataset, hue='gender')
plt.show()

# %%
sns.countplot( x='ssc_b', data=dataset, hue='gender')
plt.show()

# %%
sns.pointplot(x= 'ssc_b', y='ssc_p', data=dataset, hue='gender')
plt.show()

# %%
sns.pointplot(x= 'ssc_b', y='ssc_p', data=dataset, hue='gender', linestyles= 'dashed', dodge=True) 
# Dodge - separate the points for each level of the `hue` variable along
# the categorical axis. Setting to `True` will apply a small default
plt.show()

# %%
sns.boxplot( data=dataset, orient='h')
plt.show()

# %%
df = sns.load_dataset("exercise")

# %%
df
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
#seaborn.factorplot was renamed to seaborn.catplot in seaborn 0.9 and has been marked as deprecated since then. 
# It was definitely removed in seaborn 0.12 (see release notes).
# I am having seaborn version 0.13.2 so the factorplot has been removed so I used catplot
sns.catplot(x= 'time', y= 'pulse', hue= 'kind', kind= 'violin', col='diet', data=df)
plt.show()

# %%
df = sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.regplot(x="total_bill", y="tip", data=df )
sns.lmplot(x="total_bill", y="tip", data=df )
plt.show()

# %%
df = sns.load_dataset("anscombe")

# %%
df
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
sns.lmplot(x='x', y='y', data= df.query("dataset == 'II'"))
plt.show()

# %%
sns.lmplot(x='x', y='y', data= df.query("dataset == 'II'"), order=2)
plt.show()

# %%
df = sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
g = sns.FacetGrid(df, col= 'time')

# %%
g.map(plt.hist, "tip")
plt.show()

# %%
df = sns.load_dataset("iris")
g = sns.PairGrid(df)

# %%
g.map(plt.scatter)
plt.show()
